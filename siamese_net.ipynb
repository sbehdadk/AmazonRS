# %%
import re
import numpy as np
from PIL import Image
from numpy import asarray

from sklearn.model_selection import train_test_split
from keras import backend as K
from keras.layers import Activation
from keras.layers import Input, Lambda, Dense, Dropout, Convolution2D, MaxPooling2D, Flatten
from keras.models import Sequential, Model
from keras.optimizers import RMSprop

# %%
def read_image(filename):
    
    # load the image
    image = Image.open(filename)
    # convert image to numpy array
    data = asarray(image)
    #print(type(data))
    # summarize shape
    #print(data.shape)

    # create Pillow image
    image2 = Image.fromarray(data)
    #print(type(image2))

    # summarize image details
    #print(image2.mode)
    #print(image2.size)
    
    return data, image2

# %%
Image.open('/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/DVI Cables/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects, Video Cables, DVI Cables_B000E8SY5G')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-3c11fabf4ce5> in <module>
# ----> 1 Image.open('/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/DVI Cables/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects, Video Cables, DVI Cables_B000E8SY5G')
#
# ~/anaconda3/envs/rs/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# ...

# %%
import imagesize

width, height = imagesize.get('/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/DVI Cables/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects, Video Cables, DVI Cables_B000E8SY5G')
print(width, height)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-fb1a74ed764e> in <module>
#       1 import imagesize
#       2
# ----> 3 width, height = imagesize.get('/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/DVI Cables/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects, Video Cables, DVI Cables_B000E8SY5G')
#       4 print(width, height)
#
# ~/anaconda3/envs/rs/lib/python3.8/site-packages/imagesize.py in get(filepath)
#      89     width = -1
#      90
# ---> 91     with open(str(filepath), 'rb') as fhandle:
#      92         head = fhandle.read(24)
#      93         size = len(head)
#
# ...

# %%
data, image2 = read_image("/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/ DVI Cables/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B00CA9GISW")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-10d6d32dd2c6> in <module>
# ----> 1 data, image2 = read_image("/home/sina/Desktop/Dataset/Electronics, Accessories & Supplies, Audio & Video Accessories, Cables & Interconnects/ DVI Cables/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B00CA9GISW")
#
# <ipython-input-2-1a8b0d148935> in read_image(filename)
#       2
#       3     # load the image
# ----> 4     image = Image.open(filename)
#       5     # convert image to numpy array
#       6     data = asarray(image)
#
# ~/anaconda3/envs/rs/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# ...

# %%
data.shape
#gr_im= Image.fromarray(im).save('gr_kolala.png')
# Out:
# (225, 300, 3)

# %%
size = 2
total_sample_size = 10000


def get_data(size, total_sample_size):
    #read the image
    image, image2 = read_image("/home/sina/Desktop/Electron/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B00CA9GISW")
    #reduce the size
    image = image[::size, ::size]
    #get the new size
    dim1 = image.shape[0]
    dim2 = image.shape[1]
    count = 0
    
    #initialize the numpy array with the shape of [total_sample, no_of_pairs, dim1, dim2]
    #x_geuine_pair = np.zeros([total_sample_size, 2, 1, dim1, dim2])  # 2 is for pairs
    x_geuine_pair = np.zeros([total_sample_size, 2, 1, 100, 100])  # 2 is for pairs
    y_genuine = np.zeros([total_sample_size, 1])
    
    for i in range(40):
        for j in range(int(total_sample_size/40)):
            ind1 = 0
            ind2 = 0
            
            #read images from same directory (genuine pair)
            #while ind1 == ind2:
                #ind1 = np.random.randint(10)
                #ind2 = np.random.randint(10)
            
            # read the two images
            img1, img11 = read_image("/home/sina/Desktop/Electron/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B00CA9GISW")
            img2, img22 = read_image('/home/sina/Desktop/Electron/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B006BG3PYU')
            
            #reduce the size and reshape
            #img1 = img1[::size, ::size]
            #img2 = img2[::size, ::size]
            img1 = np.resize(img1, (100, 100))
            img2 = np.resize(img2, (100, 100))
            
            #reshape into 2D array
            #img1 = img1[:,:,0]
            #img2 = img2[:,:,0]
            #print(img1.shape[0])
            #print(img2.shape[1])
            
            #store the images to the initialized numpy array
            x_geuine_pair[count, 0, 0, :, :] = img1
            x_geuine_pair[count, 1, 0, :, :] = img2
            
            #as we are drawing images from the same directory we assign label as 1. (genuine pair)
            y_genuine[count] = 1
            count += 1

    count = 0
    x_imposite_pair = np.zeros([total_sample_size, 2, 1, 100, 100])
    y_imposite = np.zeros([total_sample_size, 1])
    
    for i in range(int(total_sample_size/10)):
        for j in range(10):
            
            #read images from different directory (imposite pair)
            while True:
                ind1 = np.random.randint(40)
                ind2 = np.random.randint(40)
                if ind1 != ind2:
                    break
                    
            image1 = read_image("/home/sina/Desktop/Electron/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, SCSI Adapters_B0053G7YTQ")
            image2 = read_image("/home/sina/Desktop/Electron/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, Parallel Adapters/Electronics, Computers & Accessories, Cables & Accessories, Computer Cable Adapters, Parallel Adapters_B007FN910U")

            #img1 = img1[::size, ::size]
            #img2 = img2[::size, ::size]
            image1 = np.resize(image1, (100, 100))
            image2 = np.resize(image2, (100, 100))
            print(image1.shape)
            print(image2.shape)
            
            x_imposite_pair[count, 0, 0, :, :] = image1
            x_imposite_pair[count, 1, 0, :, :] = image2
            #as we are drawing images from the different directory we assign label as 0. (imposite pair)
            y_imposite[count] = 0
            count += 1
            
    #now, concatenate, genuine pairs and imposite pair to get the whole data
    X = np.concatenate([x_geuine_pair, x_imposite_pair], axis=0)/255
    Y = np.concatenate([y_genuine, y_imposite], axis=0)

    return X, Y

# %%
X, Y = get_data(size, total_sample_size)
# Out:
# (100, 100)
# (100, 100)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-215ada1e67bb> in <module>
# ----> 1 X, Y = get_data(size, total_sample_size)
#
# <ipython-input-62-2c326bfec676> in get_data(size, total_sample_size)
#      76             print(image2.shape)
#      77
# ---> 78             x_imposite_pair[count, 0, 0, :, :] = image1
#      79             x_imposite_pair[count, 1, 0, :, :] = image2
#      80             #as we are drawing images from the different directory we assign label as 0. (imposite pair)
#
# ValueError: setting an array element with a sequence.

# %%
X.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-386b8665a4c0> in <module>
# ----> 1 X.shape()
#
# NameError: name 'X' is not defined

# %%
Y.shape()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.25)

# %%
def build_base_network(input_shape):
    
    seq = Sequential()
    
    nb_filter = [6, 12]
    kernel_size = 3
    
    
    #convolutional layer 1
    seq.add(Convolution2D(nb_filter[0], kernel_size, kernel_size, input_shape=input_shape,
                          border_mode='valid', dim_ordering='th'))
    seq.add(Activation('relu'))
    seq.add(MaxPooling2D(pool_size=(2, 2)))  
    seq.add(Dropout(.25))
    
    #convolutional layer 2
    seq.add(Convolution2D(nb_filter[1], kernel_size, kernel_size, border_mode='valid', dim_ordering='th'))
    seq.add(Activation('relu'))
    seq.add(MaxPooling2D(pool_size=(2, 2), dim_ordering='th')) 
    seq.add(Dropout(.25))

    #flatten 
    seq.add(Flatten())
    seq.add(Dense(128, activation='relu'))
    seq.add(Dropout(0.1))
    seq.add(Dense(50, activation='relu'))
    return seq

# %%
input_dim = x_train.shape[2:]
img_a = Input(shape=input_dim)
img_b = Input(shape=input_dim)

# %%
base_network = build_base_network(input_dim)
feat_vecs_a = base_network(img_a)
feat_vecs_b = base_network(img_b)

# %% [markdown]
# ## energy function

# %%
def euclidean_distance(vects):
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([feat_vecs_a, feat_vecs_b])

# %% [markdown]
# ## RMS prop

# %%
epochs = 13
rms = RMSprop()

# %%
model = Model(input=[img_a, img_b], output=distance)

# %% [markdown]
# ## loss function

# %%
def contrastive_loss(y_true, y_pred):
    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0))

# %% [markdown]
# ## compile the model

# %%
model.compile(loss=contrastive_loss, optimizer=rms)

# %%
img_1 = x_train[:, 0]
img2 = x_train[:, 1]

# %%
model.fit([img_1, img2], y_train, validation_split=.25,
          batch_size=128, verbose=2, nb_epoch=epochs)

# %% [markdown]
# ## Prediction with test data

# %%
pred = model.predict([x_test[:, 0], x_test[:, 1]])

# %%
def compute_accuracy(predictions, labels):
    return labels[predictions.ravel() < 0.5].mean()

# %% [markdown]
# ## Check the model accuracy

# %%
compute_accuracy(pred, y_test)
